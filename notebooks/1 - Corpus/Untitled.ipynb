# %%
import logging
import requests
import itertools
from typing import List
from collections import Counter, defaultdict


BAD_CACHE = defaultdict(Counter)


def get_general_frequencies(
    texts: List[str],
    words: List[str],
    max_query: int = 100,
    # Blacklab specific system
    server: str = "http://localhost:8888/blacklab-server/latin-corpus-index/hits",
):
    filters = " OR ".join(["docId:"+txt.replace(":", "\\:") for txt in texts])
    cache_id = tuple(sorted(texts))
    toks = Counter()
    for word in set(words):
        if cache_id in BAD_CACHE and word in BAD_CACHE[cache_id]:
            toks[word] = BAD_CACHE[cache_id][word]
            words.remove(word)
            print("Hitting cache", word)
            
    if words:
        words = sorted(list(set(words)))
        for n in range(0, len(words), max_query):
            word_subset = words[n:n+max_query]
            print("query", word_subset)
            req = requests.post(server, data={
            #    "patt": f"[]",
                "patt": "["+" | ".join([f"lemma=\"{word}\"" for word in set(word_subset)]) + "]",
                "filter": filters,
                "outputformat": "json",
                "wordsaroundhit": 0,
                "group": "hit:lemma:s",
                "first":0,
                "maxretrieve": -1,
                "waitfortotal": "yes",
                "maxcount": -1
            })
            json = req.json()
            toks.update({
                tok["identityDisplay"]: tok["size"]
                for tok in json["hitGroups"]
            })
    
    for word in toks:
        BAD_CACHE[cache_id][word] = toks[word]
    return toks   

import time
start = time.time()
get_general_frequencies([], ["mentula", "lasciuus"])
end = (time.time() - start) / 60
print(end)
# Out:
# query ['lasciuus', 'mentula']
# 0.00019690990447998046

# %%
start = time.time()
get_general_frequencies([], ['soror', 'audeo', 'duco', 'priapium', 'sum1', "priapum", "lasciuus"], max_query=2)
end = (time.time() - start) / 60
print(end)
# Out:
# Hitting cache lasciuus
# query ['audeo', 'duco']
# query ['priapium', 'priapum']
# query ['soror', 'sum1']
# 0.031162325541178384

# %%
start = time.time()
get_general_frequencies([], ['soror', 'audeo', 'duco', 'priapium', 'sum1', "priapum", "lasciuus"])
end = (time.time() - start) / 60
print(end)
# Out:
# Hitting cache soror
# Hitting cache lasciuus
# Hitting cache sum1
# Hitting cache audeo
# Hitting cache priapium
# Hitting cache duco
# 0.008697144190470378

# %%
SERVER = "http://localhost:8888/blacklab-server/latin-corpus-index/hits"
GLOBAL_WINDOW = 10
MIN_FREQ = 10
COOC_MIN_FREQ = 20
NORMALIZATION: str = "ratio"
IGNORE_WORDS = ("sum1", "que", "habeo", "dico2", "facio", "possum1", "do", "uideo", "uolo3", "iam", "sic",
               "tamen", "tam", "puto", "res", "suus")
TEXTS = ["urn:cts:latinLit:phi1294.phi002.perseus-lat2", "urn:cts:latinLit:phi1103.phi001.lascivaroma-lat1"]
LEMMAS = ['soror', 'audeo', 'duco', 'priapium', 'sum1']

filters = " OR ".join(["docId:"+txt.replace(":", "\\:") for txt in TEXTS])
req = requests.post(SERVER, data={
#    "patt": f"[]",
    "patt": "["+" | ".join([f"lemma=\"{word}\"" for word in LEMMAS]) + "]",
    "filter": filters,
    "outputformat": "json",
    "wordsaroundhit": 0,
    "group": "hit:lemma:s",
    "first":0,
    #"number": -1,
    "maxretrieve": -1,
    "waitfortotal": "yes",
    "maxcount": -1
})
data = req.json()
data
# Out:
# {'summary': {'searchParam': {'filter': 'docId:urn\\:cts\\:latinLit\\:phi1294.phi002.perseus-lat2 OR docId:urn\\:cts\\:latinLit\\:phi1103.phi001.lascivaroma-lat1',
#    'first': '0',
#    'group': 'hit:lemma:s',
#    'indexname': 'latin-corpus-index',
#    'maxcount': '-1',
#    'maxretrieve': '-1',
#    'patt': '[lemma="soror" | lemma="audeo" | lemma="duco" | lemma="priapium" | lemma="sum1"]',
#    'waitfortotal': 'yes',
#    'wordsaroundhit': '0'},
#   'searchTime': 201,
#   'numberOfGroups': 5,
#   'largestGroupSize': 2019,
#   'windowFirstResult': 0,
#   'requestedWindowSize': 50,
#   'actualWindowSize': 5,
#   'windowHasPrevious': False,
#   'windowHasNext': False,
#   'stillCounting': False,
#   'numberOfHits': 2105,
#   'numberOfHitsRetrieved': 2105,
#   'stoppedCountingHits': False,
#   'stoppedRetrievingHits': False,
#   'numberOfDocs': 2,
#   'numberOfDocsRetrieved': 2,
#   'subcorpusSize': {'documents': 2, 'tokens': 76198}},
#  'hitGroups': [{'identity': 'cws:lemma:s:sum1',
#    'identityDisplay': 'sum1',
#    'size': 2019,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:soror',
#    'identityDisplay': 'soror',
#    'size': 34,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:duco',
#    'identityDisplay': 'duco',
#    'size': 32,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:audeo',
#    'identityDisplay': 'audeo',
#    'size': 19,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:priapium',
#    'identityDisplay': 'priapium',
#    'size': 1,
#    'numberOfDocs': 1}]}

# %%
# Out:
# {'summary': {'searchParam': {'filter': 'docId:urn\\:cts\\:latinLit\\:phi1294.phi002.perseus-lat2 OR docId:urn\\:cts\\:latinLit\\:phi1103.phi001.lascivaroma-lat1',
#    'first': '0',
#    'group': 'hit:lemma:s',
#    'indexname': 'latin-corpus-index',
#    'maxcount': '-1',
#    'maxretrieve': '-1',
#    'patt': '[]',
#    'waitfortotal': 'yes',
#    'wordsaroundhit': '0'},
#   'searchTime': 310,
#   'numberOfGroups': 6990,
#   'largestGroupSize': 8275,
#   'windowFirstResult': 0,
#   'requestedWindowSize': 50,
#   'actualWindowSize': 50,
#   'windowHasPrevious': False,
#   'windowHasNext': True,
#   'stillCounting': False,
#   'numberOfHits': 76198,
#   'numberOfHitsRetrieved': 76198,
#   'stoppedCountingHits': False,
#   'stoppedRetrievingHits': False,
#   'numberOfDocs': 2,
#   'numberOfDocsRetrieved': 2,
#   'subcorpusSize': {'documents': 2, 'tokens': 76198}},
#  'hitGroups': [{'identity': 'cws:lemma:s:$CM',
#    'identityDisplay': ',',
#    'size': 8275,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:.',
#    'identityDisplay': '.',
#    'size': 3462,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:sum1',
#    'identityDisplay': 'sum1',
#    'size': 2019,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:tu',
#    'identityDisplay': 'tu',
#    'size': 1414,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:et2',
#    'identityDisplay': 'et2',
#    'size': 1413,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:$CL',
#    'identityDisplay': ':',
#    'size': 1294,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:qui1',
#    'identityDisplay': 'qui1',
#    'size': 1227,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:que',
#    'identityDisplay': 'que',
#    'size': 1190,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:non',
#    'identityDisplay': 'non',
#    'size': 953,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:hic1',
#    'identityDisplay': 'hic1',
#    'size': 797,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:?',
#    'identityDisplay': '?',
#    'size': 733,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ego',
#    'identityDisplay': 'ego',
#    'size': 714,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:nec2',
#    'identityDisplay': 'nec2',
#    'size': 584,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:si2',
#    'identityDisplay': 'si2',
#    'size': 514,
#    'numberOfDocs': 2},
#   {'identity': "cws:lemma:s:'",
#    'identityDisplay': "'",
#    'size': 507,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:sed',
#    'identityDisplay': 'sed',
#    'size': 462,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:;',
#    'identityDisplay': ';',
#    'size': 455,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:in',
#    'identityDisplay': 'in',
#    'size': 442,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:do',
#    'identityDisplay': 'do',
#    'size': 426,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:cum3',
#    'identityDisplay': 'cum3',
#    'size': 421,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:quis1',
#    'identityDisplay': 'quis1',
#    'size': 401,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:tuus',
#    'identityDisplay': 'tuus',
#    'size': 395,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:possum1',
#    'identityDisplay': 'possum1',
#    'size': 367,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:dico2',
#    'identityDisplay': 'dico2',
#    'size': 327,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ille',
#    'identityDisplay': 'ille',
#    'size': 319,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:facio',
#    'identityDisplay': 'facio',
#    'size': 283,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:meus',
#    'identityDisplay': 'meus',
#    'size': 245,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:habeo',
#    'identityDisplay': 'habeo',
#    'size': 243,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:uolo3',
#    'identityDisplay': 'uolo3',
#    'size': 235,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:uideo',
#    'identityDisplay': 'uideo',
#    'size': 224,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:noster',
#    'identityDisplay': 'noster',
#    'size': 208,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ut4',
#    'identityDisplay': 'ut4',
#    'size': 205,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:iam',
#    'identityDisplay': 'iam',
#    'size': 199,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ad2',
#    'identityDisplay': 'ad2',
#    'size': 192,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:nihil',
#    'identityDisplay': 'nihil',
#    'size': 181,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:suus',
#    'identityDisplay': 'suus',
#    'size': 181,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ipse',
#    'identityDisplay': 'ipse',
#    'size': 180,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:de',
#    'identityDisplay': 'de',
#    'size': 178,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:magnus',
#    'identityDisplay': 'magnus',
#    'size': 167,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:sic',
#    'identityDisplay': 'sic',
#    'size': 166,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:omnis',
#    'identityDisplay': 'omnis',
#    'size': 161,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:puer',
#    'identityDisplay': 'puer',
#    'size': 159,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:—',
#    'identityDisplay': '—',
#    'size': 156,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:nos',
#    'identityDisplay': 'nos',
#    'size': 155,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:ab',
#    'identityDisplay': 'ab',
#    'size': 154,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:mitto',
#    'identityDisplay': 'mitto',
#    'size': 150,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:puto',
#    'identityDisplay': 'puto',
#    'size': 150,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:totus',
#    'identityDisplay': 'totus',
#    'size': 145,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:uenio',
#    'identityDisplay': 'uenio',
#    'size': 144,
#    'numberOfDocs': 2},
#   {'identity': 'cws:lemma:s:dum2',
#    'identityDisplay': 'dum2',
#    'size': 144,
#    'numberOfDocs': 2}]}
